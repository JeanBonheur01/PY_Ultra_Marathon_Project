# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")
# Out:
# /var/folders/9h/j7gjt47j6w9cb8p93spj_h8w0000gn/T/ipykernel_80574/2350612576.py:1: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("TWO_CENTURIES_OF_UM_RACES.csv")

# %%
df.head (10)
# Out:
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# ...

# %%
df.shape
# Out:
# (7461195, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                     int64
# dtype: object

# %% [markdown]
# #clean up data
# #Only want USA Races, 50k or 50Mi, year 2020

# %% [markdown]
# #Step1 show 50km or 50Mi
# #test 50km (50k, 50kmi, etc)

# %%
df[df['Event distance/length'] == '50km']
# Out:
#          Year of event Event dates                             Event name  \
# 0                 2018  06.01.2018                    Selva Costera (CHI)
# 1                 2018  06.01.2018                    Selva Costera (CHI)
# 2                 2018  06.01.2018                    Selva Costera (CHI)
# 3                 2018  06.01.2018                    Selva Costera (CHI)
# 4                 2018  06.01.2018                    Selva Costera (CHI)
# ...                ...         ...                                    ...
# 7461089           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461090           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461091           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461092           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
# 7461093           1995  07.01.1995  Centenary Lakes 50 Km Track Run (AUS)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #test 50mi(50m, 50mil, etc)

# %%
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %% [markdown]
# #combine 50k and 50mi within isin
# #select only year 2020

# %%
df[(df['Event distance/length'].isin(['50km' , '50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...

# %% [markdown]
# #control if we have the event/value "Everglades 50 Mile Ultra Run (USA)" in the dataset

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']
# Out:
#          Year of event Event dates                          Event name  \
# 51923             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51924             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51925             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51926             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# 51927             2018  17.02.2018  Everglades 50 Mile Ultra Run (USA)
# ...                ...         ...                                 ...
# 6417091           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417092           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417093           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417094           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
# 6417095           2015  21.02.2015  Everglades 50 Mile Ultra Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #split event name to extract only USA value

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)']['Event name'].str.split('(').str.get(1).str.split(')').str.get(0)
# Out:
# 51923      USA
# 51924      USA
# 51925      USA
# 51926      USA
# 51927      USA
#           ...
# 6417091    USA
# 6417092    USA
# 6417093    USA
# 6417094    USA
# 6417095    USA
# Name: Event name, Length: 338, dtype: object

# %%
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 7461181           1995  07.01.1995
# 7461182           1995  07.01.1995
# 7461183           1995  07.01.1995
# 7461184           1995  07.01.1995
# 7461185           1995  07.01.1995
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...

# %% [markdown]
# #combine all the filters togheter

# %%
df[(df['Event distance/length'].isin(['50km' , '50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2 = df[(df['Event distance/length'].isin(['50km' , '50mi'])) & (df['Year of event'] == 2020) & (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')]

# %%
df2.head(10)
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# 2539950           2020  02.02.2020
# 2539951           2020  02.02.2020
# 2539952           2020  02.02.2020
# 2539953           2020  02.02.2020
# 2539954           2020  02.02.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539950  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...

# %%
df2.shape
# Out:
# (26090, 13)

# %% [markdown]
# #since all data is from USA race, remove (USA) from event name

# %%
df2['Event name'].str.split('(').str.get(0)
# Out:
# 2539945    West Seattle Beach Run - Winter Edition
# 2539946    West Seattle Beach Run - Winter Edition
# 2539947    West Seattle Beach Run - Winter Edition
# 2539948    West Seattle Beach Run - Winter Edition
# 2539949    West Seattle Beach Run - Winter Edition
#                              ...
# 2760957     Yankee Springs Fall Trail Run Festival
# 2760958     Yankee Springs Fall Trail Run Festival
# 2760959     Yankee Springs Fall Trail Run Festival
# 2760960     Yankee Springs Fall Trail Run Festival
# 2760961     Yankee Springs Fall Trail Run Festival
# Name: Event name, Length: 26090, dtype: object

# %%
#df2['Event name'] = df2['Event name'].str.split('(').str.get(0)  or
df2.loc[:, 'Event name'] = df2['Event name'].str.split('(').str.get(0)

# %% [markdown]
# .loc[row_indexer,col_indexer] = value instead    #This is used when trying to replace correctly a value in the DataFrame

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #clean up athlet age

# %%
df2.loc[:, 'Athlete year of birth'] = df2['Athlete year of birth'].fillna(0)

# %%
df2.loc[:, 'athlete_age'] = 2020 - df2['Athlete year of birth'].astype(int)
# Out:
# /var/folders/9h/j7gjt47j6w9cb8p93spj_h8w0000gn/T/ipykernel_80574/1099865090.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2.loc[:, 'athlete_age'] = 2020 - df2['Athlete year of birth'].astype(int)

# %% [markdown]
# #remove h from athlete performance

# %%
df2.loc[:, 'Athlete performance'] = df2['Athlete performance'].str.split(' ').str.get(0)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #drop unwanted columns: Athlete club, Athlete Country, Athlete year of birth, Athlete Age Category

# %%
df2 = df2.drop(['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis =1)

# %%
df2.head(10)
# Out:
#          Year of event Event dates                                Event name  \
# 2539945           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953           2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954           2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #clean up null values

# %%
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %% [markdown]
# #It seems like the dataset has not null value
# # otherwise we would have drop it with this code:   df2 = df2.dropna()

# %%
df2.shape
# Out:
# (26090, 10)

# %% [markdown]
# #check for dupes (duplicates)

# %%
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %% [markdown]
# #reset index

# %%
df2.reset_index(drop = True)
# Out:
#        Year of event Event dates                                Event name  \
# 0               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 1               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 3               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 4               2020  02.02.2020  West Seattle Beach Run - Winter Edition
# ...              ...         ...                                       ...
# 26085           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26086           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26087           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26088           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
# 26089           2020  03.10.2020   Yankee Springs Fall Trail Run Festival
#
#       Event distance/length  Event number of finishers Athlete performance  \
# ...

# %% [markdown]
# #fix types

# %%
df2.dtypes
# Out:
# Year of event                 int64
# Event dates                  object
# Event name                   object
# Event distance/length        object
# Event number of finishers     int64
# Athlete performance          object
# Athlete gender               object
# Athlete average speed        object
# Athlete ID                    int64
# athlete_age                   int64
# dtype: object

# %%
#We want to make 'Athlete average speed' to a float

# %%
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                     int64
# athlete_age                    int64
# dtype: object

# %% [markdown]
# #rename columns

# %%
df2 = df2.rename (columns = {'Year of event': 'year', 
                             'Event dates': 'race_date', 
                             'Event name': 'race_name', 
                             'Event distance/length': 'race_distance', 
                             'Event number of finishers': 'number_of_finishers', 
                             'Athlete performance': 'performance', 
                             'Athlete gender': 'gender', 
                             'Athlete average speed': 'average_speed', 
                             'Athlete ID': 'ID', 
                             'athlete_age': 'age', 
                            } )

# %%
df2.head(10)
# Out:
#          year   race_date                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_distance  number_of_finishers performance gender  average_speed  \
# 2539945          50km                   20     3:17:55      M         15.158
# ...

# %% [markdown]
# #reorder columns

# %%
df3 = df2[['year', 'race_date', 'race_name', 'race_distance', 'number_of_finishers', 'ID', 'age', 'gender','average_speed', 'performance']]

# %%
df3.head(10)
# Out:
#          year   race_date                                 race_name  \
# 2539945  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539946  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539947  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539948  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539949  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539950  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539951  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539952  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539953  2020  02.02.2020  West Seattle Beach Run - Winter Edition
# 2539954  2020  02.02.2020  West Seattle Beach Run - Winter Edition
#
#         race_distance  number_of_finishers      ID  age gender  average_speed  \
# 2539945          50km                   20   71287   29      M         15.158
# ...

# %% [markdown]
# #all race are already in 2020, so drop the year column

# %%
df3 = df3.drop(['year'], axis=1)

# %%
df3.head(10)
# Out:
#           race_date                                 race_name race_distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539950  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539951  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539952  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539953  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539954  02.02.2020  West Seattle Beach Run - Winter Edition           50km
#
#          number_of_finishers      ID  age gender  average_speed performance
# ...

# %% [markdown]
# #Export and save the output

# %%
df3.to_csv('EDA_output.csv', index=False)

# %% [markdown]
# #Findings:
# #find 2 races in 2020 - Sarasota | Everglades
# #for athlete_id = 222509

# %%
df3[df3['race_name'] == 'Everglades 50 Mile Ultra Run ']
# Out:
#           race_date                      race_name race_distance  \
# 2591476  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591477  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591478  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591479  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591480  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591481  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591483  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591484  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591485  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591486  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591487  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2591488  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# ...

# %%
df3[df3['ID'] == 222509]
# Out:
#           race_date                      race_name race_distance  \
# 2591482  14.03.2020  Everglades 50 Mile Ultra Run           50mi
# 2616900  22.02.2020       Manasota Track Club 50K           50km
#
#          number_of_finishers      ID  age gender  average_speed performance
# 2591482                   40  222509   23      M          8.634     9:19:10
# 2616900                   36  222509   23      M         10.371     4:49:16

# %% [markdown]
# #charts and graphs

# %%
sns.histplot(df3['race_distance'])
# Out:
# <Axes: xlabel='race_distance', ylabel='Count'>

# %% [markdown]
# #This shows that more athlets run the 50Km race than the 50mi

# %%
sns.histplot(df3, x = 'race_distance', hue = 'gender')
# Out:
# <Axes: xlabel='race_distance', ylabel='Count'>

# %% [markdown]
# #The output indicates that for the 50Km distance, the participation is almost equal between males and females. However, the 50mi distance is dominated by men."

# %%
sns.displot(df3[df3['race_distance'] == '50mi']['average_speed'])

# %% [markdown]
# #This shows the distribution of average speed. It is very common for average speed to be between 6 and 8 in both race types.

# %%
sns.violinplot(data= df3, x = 'race_distance', y= 'average_speed', hue = 'gender')
# Out:
# <Axes: xlabel='race_distance', ylabel='average_speed'>

# %% [markdown]
# #The resulting violin plot represents the distribution of average speeds for participants in the 50KM and 50mi races, while also comparing the distributions between males and females.
#
# #This may suggest that the distribution of average speeds for participants in races with a distance of 50 kilometers is more concentrated around certain values compared to races with a distance of 50 miles, where the distribution is more spread out and covers a broader range of speeds.
# We can also note that the average speed for male participants in the races tends to be higher and more concentrated around certain values, while the average speed for female participants is lower and spread over a wider range.
# These observations provide indications of potential differences in performance or distribution of speeds between different types of races and between genders. It is important to analyze these patterns more carefully and possibly conduct statistical analyses to draw more reliable conclusions.

# %%
sns.violinplot(data= df3, x = 'race_distance', y= 'average_speed', hue = 'gender', split = True, inner = 'quart', linewidth=1)
# Out:
# <Axes: xlabel='race_distance', ylabel='average_speed'>

# %%
sns.lmplot(data=df3, x= 'age', y= 'average_speed', hue= 'gender')

# %% [markdown]
# #Overall, men tend to run faster than women, and the average speed decreases as you get older for the both gender

# %% [markdown]
# #Findings questions:

# %% [markdown]
# #Difference in speed for the 50Km, 50mi male to female

# %%
df3.groupby(['race_distance', 'gender'])['average_speed'].mean()
# Out:
# race_distance  gender
# 50km           F         7.083843
#                M         7.737665
# 50mi           F         6.829343
#                M         7.253770
# Name: average_speed, dtype: float64

# %% [markdown]
# #Men have a higher average than women in both races, but that differance is not hinger in the 50mi race.

# %% [markdown]
# #Men have a higher average than women in both races, but that difference is not higher in the 50mi race.

# %%
df3.query('race_distance == "50mi"').groupby('age') ['average_speed'].agg (['mean', 'count']).sort_values('mean', ascending = False).query('count>19')
#shows the fastest runners
# Out:
#           mean  count
# age
# 29    7.902252    135
# 23    7.779800     55
# 28    7.575252    107
# 30    7.569204    157
# 25    7.540923     91
# 31    7.451638    138
# 38    7.430022    231
# 35    7.422359    195
# 36    7.403854    185
# 26    7.379800     75
# 33    7.379188    149
# 22    7.367902     41
# 24    7.354274     73
# 42    7.327656    209
# 34    7.319011    182
# 40    7.310669    236
# 21    7.304658     38
# 20    7.293778     27
# 32    7.287969    162
# 39    7.283648    227
# 37    7.220493    221
# 27    7.201748    119
# 41    7.197017    179
# 45    7.130667    156
# 47    7.085410    156
# 44    7.052642    179
# 51    7.019379    124
# 46    6.897236    174
# 43    6.884225    187
# 52    6.847400    130
# 55    6.828623     69
# 54    6.805506     83
# 49    6.789553    159
# 57    6.783205     78
# 53    6.736969     96
# 56    6.708373     67
# 48    6.696853    136
# 59    6.672072     83
# 50    6.671541    172
# 64    6.620727     22
# ...

# %%
df3.query('race_distance == "50mi"').groupby('age') ['average_speed'].agg (['mean', 'count']).sort_values('mean', ascending = True).query('count>19')
#shows the lowest runners
# Out:
#           mean  count
# age
# 60    6.261788     33
# 62    6.272730     37
# 61    6.358355     31
# 63    6.514806     31
# 2020  6.575293     41
# 58    6.582328     67
# 64    6.620727     22
# 50    6.671541    172
# 59    6.672072     83
# 48    6.696853    136
# 56    6.708373     67
# 53    6.736969     96
# 57    6.783205     78
# 49    6.789553    159
# 54    6.805506     83
# 55    6.828623     69
# 52    6.847400    130
# 43    6.884225    187
# 46    6.897236    174
# 51    7.019379    124
# 44    7.052642    179
# 47    7.085410    156
# 45    7.130667    156
# 41    7.197017    179
# 27    7.201748    119
# 37    7.220493    221
# 39    7.283648    227
# 32    7.287969    162
# 20    7.293778     27
# 21    7.304658     38
# 40    7.310669    236
# 34    7.319011    182
# 42    7.327656    209
# 24    7.354274     73
# 22    7.367902     41
# 33    7.379188    149
# 26    7.379800     75
# 36    7.403854    185
# 35    7.422359    195
# 38    7.430022    231
# ...

# %% [markdown]
# #Athletes who are 29 years old are the fastest, with the highest mean in the dataset, followed by those who are 23, 28, 30, and 25 years old. Overall, athletes between 25 and 30 years old are the fastest in the race. Athletes between of 50 and above have the lowest average speed.

# %% [markdown]
# #Seasons for the data --> Slower in summer than winter?
#
# #sprint 3-5
# #summer 6-8
# #fall 9-11
# #winter 12-2
#
# #split between two decimals

# %%
df3['race_month']= df3['race_date'].str.split('.').str.get(1).astype(int)

# %%
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Sprint' if x >2 else 'Winter')
df3.head()
# Out:
#           race_date                                 race_name race_distance  \
# 2539945  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539946  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539947  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539948  02.02.2020  West Seattle Beach Run - Winter Edition           50km
# 2539949  02.02.2020  West Seattle Beach Run - Winter Edition           50km
#
#          number_of_finishers      ID  age gender  average_speed performance  \
# 2539945                   20   71287   29      M         15.158     3:17:55
# 2539946                   20  629508   39      M         12.369     4:02:32
# 2539947                   20   64838   21      M         12.099     4:07:57
# 2539948                   20  704450   37      M         11.449     4:22:02
# 2539949                   20  810281   43      M         11.212     4:27:34
#
#          race_month race_season
# ...

# %% [markdown]
# #The month was extracted from the race_date, and then conditions was used in the query to determine the seanson of the race.

# %%
df3.groupby('race_season')['average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Sprint       7.672551   3357
# Winter       7.519917  11659
# Fall         7.403707   8407
# Summer       6.872740   2667

# %% [markdown]
# #We can notice that athletes perform better and faster in the spring, followed by winter and fall. However, their performance is lower in the summer when it is warmer."

# %% [markdown]
# #For 50 miler only

# %%
df3.query('race_distance == "50mi"').groupby('race_season')['average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Fall         7.496351   2019
# Sprint       7.073452    847
# Winter       7.049402   1982
# Summer       6.515813    820
